# %% [markdown]
# #Chapter 7

# %% [markdown]
# ##Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_name = input("Enter the file name: ")

try:
    with open(file_name, 'r') as file:
        for line in file:
            print(line.upper(), end='')
except FileNotFoundError:
    print("File not found.")
except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter the file name: /content/drive/MyDrive/Python_Workbook_2/exercise.txt
# DYNN ALEKSANDR BASCO
# ALLISA JANE GALARIO
# HANNAH SEDOTES

# %% [markdown]
# ##Exercise 2

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.

# %%
file_name = open('/content/drive/MyDrive/Python_Workbook_2/exercise.txt')
text = file_name.read()
print(len(text))
# Out:
# 55

# %% [markdown]
# ##Challenge

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %% [markdown]
# X-DSPAM-Confidence: 0.8475

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %% [markdown]
# Enter the file name: mbox.txt Average spam confidence: 0.894128046745
#
# Enter the file name: mbox-short.txt Average spam confidence: 0.750718518519

# %%
file_name = input("Enter the file name: ")

try:
    with open(file_name, 'r') as file:
        total_confidence = 0
        count = 0

        for line in file:
            if line.startswith('X-DSPAM-Confidence:'):
                confidence_str = line.split(':')[1].strip()
                try:
                    total_confidence += float(confidence_str)
                    count += 1
                except ValueError:
                    print("Error: Invalid confidence value '{}'".format(confidence_str))

        if count > 0:
            print("Average spam confidence:", total_confidence / count)
        else:
            print("No 'X-DSPAM-Confidence' lines found in the file.")

except FileNotFoundError:
    print("File not found:", file_name)
except PermissionError:
    print("Permission denied:", file_name)
except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter the file name: /content/drive/MyDrive/Python_Workbook_2/challenge.txt
# Average spam confidence: 0.8475
